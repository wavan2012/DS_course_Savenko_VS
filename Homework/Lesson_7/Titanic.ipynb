# %%
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# Считывание датафрейма. Считайте датафрейм и сделайте при считывании все признаки строковыми (hints: используйте dtype)
dt = pd.read_csv("data/titanic/train.csv")
dst = pd.read_csv("data/space_titanic/train.csv")

dt.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
dt_str = pd.DataFrame(dt, columns=[el for el in dt], dtype=str)
dst_str = pd.DataFrame(dst, columns=[el for el in dt], dtype=str)

# %%
dt.info()
dt_str.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...

# %%
dst.info()
dst_str.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerId   8693 non-null   object
#  1   HomePlanet    8492 non-null   object
#  2   CryoSleep     8476 non-null   object
#  3   Cabin         8494 non-null   object
#  4   Destination   8511 non-null   object
#  5   Age           8514 non-null   float64
#  6   VIP           8490 non-null   object
#  7   RoomService   8512 non-null   float64
#  8   FoodCourt     8510 non-null   float64
#  9   ShoppingMall  8485 non-null   float64
#  10  Spa           8510 non-null   float64
#  11  VRDeck        8505 non-null   float64
#  12  Name          8493 non-null   object
#  13  Transported   8693 non-null   bool
# dtypes: bool(1), float64(6), object(7)
# memory usage: 891.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 12 columns):
# ...

# %%
#Выведите несколько первых, последних, случайных строк (случайные используя встроенный метод и сгенерируйте массив из случайных индексов, по которым будут браться строки)
dt.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
dt.tail(2)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 889      0  111369  30.00  C148        C
# 890      0  370376   7.75   NaN        Q

# %%
dt.sample(2)
# Out:
#      PassengerId  Survived  Pclass                        Name   Sex   Age  \
# 157          158         0       3             Corn, Mr. Harry  male  30.0
# 544          545         0       1  Douglas, Mr. Walter Donald  male  50.0
#
#      SibSp  Parch           Ticket     Fare Cabin Embarked
# 157      0      0  SOTON/OQ 392090    8.050   NaN        S
# 544      1      0         PC 17761  106.425   C86        C

# %%
dt_rand = pd.DataFrame(dt, index=sorted(dt['PassengerId'], key=lambda x: random.random()))
#dt_rand[dt_rand.PassengerId==666]
dt_rand[:2]
# Out:
#      PassengerId  Survived  Pclass                    Name   Sex   Age  SibSp  \
# 212        213.0       0.0     3.0  Perkin, Mr. John Henry  male  22.0    0.0
# 725        726.0       0.0     3.0     Oreskovic, Mr. Luka  male  20.0    0.0
#
#      Parch     Ticket    Fare Cabin Embarked
# 212    0.0  A/5 21174  7.2500   NaN        S
# 725    0.0     315094  8.6625   NaN        S

# %%
#Преобразования показателей. Обработайте каждый показатель в соответствии с тем типом данных, которым он должен быть (из первого пункта у нас должны быть изначально все показатели str типа)
dt_no_str = dt_str
list_int64 =["PassengerId", "Survived", "Pclass", "SibSp", "Parch"]
dt_no_str[list_int64] = dt_str[list_int64].astype('int64')
dt_no_str[["Age", "Fare"]] = dt_str[["Age", "Fare"]].astype('float64')
dt_no_str.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#Обработайте пропуски
all_arg_list = ["PassengerId", "Survived", "Pclass", "Name", "Sex", "Age", "SibSp", "Parch", "Ticket", "Fare", "Cabin", "Embarked"]
dt_NoNone = dt
dt_NoNone["Embarked"] = dt_NoNone["Embarked"].fillna("S")
dt_NoNone["Age"] = dt_NoNone["Age"].fillna(dt["Age"].median())
#dt_NoNone["Age"].value_counts(dropna=False)
dt_NoNone.info()
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...

# %%
#experiment

# Fixing random state for reproducibility
def gr_experimental():
    np.random.seed(19680801)
 
    dt = 0.01
    t = np.arange(0, 30, dt)
    nse1 = np.random.randn(len(t))                 # white noise 1
    nse2 = np.random.randn(len(t))                 # white noise 2

    # Two signals with a coherent part at 10 Hz and a random part
    s1 = np.sin(2 * np.pi * 10 * t) + nse1
    s2 = np.sin(2 * np.pi * 10 * t) + nse2

    fig, axs = plt.subplots(2, 1)
    axs[0].plot(t, s1, t, s2)
    axs[0].set_xlim(0, 2)
    axs[0].set_xlabel('Time')
    axs[0].set_ylabel('s1 and s2')
    axs[0].grid(True)

    cxy, f = axs[1].cohere(s1, s2, 256, 1. / dt)
    axs[1].set_ylabel('Coherence')

    fig.tight_layout()
    plt.show()
gr_experimental()

# %%
dt["Age"].agg(["mean","median", "min", "max"])
# Out:
# mean      29.361582
# median    28.000000
# min        0.420000
# max       80.000000
# Name: Age, dtype: float64

# %%
#--------------------------------------------------------------------------------------
#    Функции для вывода количества выживших в процентах от возроста
#--------------------------------------------------------------------------------------
def list_SurvivedPersent_to_Age(dif: float):
    list = []
    for i in range(1, 80):
        df = dt[(dt.Age >= i - dif) & (dt.Age <= i + dif)]
        count = df["Survived"].count()
        sum = df["Survived"].sum()
        list.append(sum/count) 
    return list

def list_SurvivedFemalePersent_to_Age(dif: float):
    list = []
    for i in range(1, 80):
        df = dt[(dt.Age >= i - dif) & (dt.Age <= i + dif) & (dt.Sex == "female")]
        count = df["Survived"].count()
        sum = df["Survived"].sum()
        list.append(sum/count, ) 
    return list

def list_SurvivedMalePersent_to_Age(dif: float):
    list = []
    for i in range(1, 80):
        df = dt[(dt.Age >= i - dif) & (dt.Age <= i + dif) & (dt.Sex == "male")]
        count = df["Survived"].count()
        sum = df["Survived"].sum()
        list.append(sum/count) 
    return list

def list_of_Indexes():
    list = []
    for i in range(1, 80):
        list.append(i)
    return list

# %%
def gr_SurvivedPersent_to_Age(dif: float):
   
    # 
    fig = plt.figure(figsize=(12, 4))
    ax = fig.add_subplot()
    list_Survived: list = list_SurvivedPersent_to_Age(dif)
    list_SurvivedWoman: list = list_SurvivedFemalePersent_to_Age(dif)
    list_SurvivedMan: list = list_SurvivedMalePersent_to_Age(dif)
    list_Age: list = list_of_Indexes()
    ax.plot (list_Age,  list_Survived, label="survived")
    ax.plot (list_Age, list_SurvivedWoman, label="survived Female")
    ax.plot (list_Age, list_SurvivedMan, label="survived Male")
    ax.grid(True)
    ax.set_xticks(np.arange(0, 85, 5))
    ax.set_yticks(np.arange(0, 1.1, 0.1))
    ax.legend(bbox_to_anchor=(1,1), loc="upper left")
    fig.suptitle("вероятность выжить от возроста")
    plt.show()
gr_SurvivedPersent_to_Age(1.)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9676\1830065072.py:10: RuntimeWarning: invalid value encountered in scalar divide
#   list.append(sum/count)
# C:\Users\user\AppData\Local\Temp\ipykernel_9676\1830065072.py:19: RuntimeWarning: invalid value encountered in scalar divide
#   list.append(sum/count, )
# C:\Users\user\AppData\Local\Temp\ipykernel_9676\1830065072.py:28: RuntimeWarning: invalid value encountered in scalar divide
#   list.append(sum/count)
